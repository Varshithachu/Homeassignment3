# %%
# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
import random
import sys
import os

# Load and preprocess the text dataset
path = tf.keras.utils.get_file('shakespeare.txt', origin='https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')
text = open(path, 'rb').read().decode(encoding='utf-8').lower()
print(f'Corpus length: {len(text)} characters')

# Create character mappings
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Prepare sequences
maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print(f'Number of sequences: {len(sentences)}')

# One-hot encode the data
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool_)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool_)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam')

# Helper function to sample predictions with temperature
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-8) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# Train and generate text
for epoch in range(1, 5):
    print(f'\nEpoch {epoch}')
    model.fit(x, y, batch_size=128, epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for temperature in [0.2, 0.5, 1.0]:
        print(f'\n----- Temperature: {temperature}')
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print(f'----- Generating with seed: "{sentence}"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1115394/1115394 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Corpus length: 1115394 characters
# Number of sequences: 371785
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1
# 2905/2905 ━━━━━━━━━━━━━━━━━━━━ 313s 107ms/step - loss: 2.6102
#
# ----- Temperature: 0.2
# ----- Generating with seed: "ir counsels and their cares, digest thin"
# ir counsels and their cares, digest thing the mord the will the his the word the with me the mant the hard the mare the hard me the with the sond the hard the mare the for the have to he ward the mard the have the hard the hard the for the mand he mard the her the her the her the hing the his sore the his sor the with the buth me the beand the mere the come the hare the mart the hard the bere to mo to the come and come the hard the and
#
# ----- Temperature: 0.5
# ----- Generating with seed: "ir counsels and their cares, digest thin"
# ir counsels and their cares, digest thing ancenist to her buch stee to you be cone bor the the with hak to her donger mord wir ghe in the mars our beathe so no seer love som mor i gon wath then seand i come, i will whing him bold conte have the sirs in wirp and the covint manite her are her my to mong woth monger i his dath hie herd the benter heat me the with row stand this no whed ho come whe here south for he cond come the fard in th
#
# ----- Temperature: 1.0
# ----- Generating with seed: "ir counsels and their cares, digest thin"
# ir counsels and their cares, digest thingerce,
# wald heve ing haven, mo seed with's senet ham, yom iy stilkn both me hiy swold as hemfole if ke joest fruth, o grood:
# ards re hims; he gied
# shild then, breik jtong lt.
#
# buge:
# thes or thele wo al te eal.
#  gave;
# liceand vim.
# agconger yorbes'n crinaeds hate sof comncli.
#
# ghefer: larw ir! mads selmad, thy ; veann gowm,
# murte sance cuafer, troue:
#
# okee dise ho skent
# cofes
# math te ferat's, foime
#
# Epoch 2
# 2905/2905 ━━━━━━━━━━━━━━━━━━━━ 307s 106ms/step - loss: 2.0375
#
# ----- Temperature: 0.2
# ----- Generating with seed: "and and strength could equal them.
# well,"
# and and strength could equal them.
# well, thee she the warke of the warder the warder the with here the will the counder the conner his conder the with of the comenter with the will the will thee seether the worde the conder with thee thee deen the king the ward the will here the warde the with the come the with here thee sone,
# the warther the warke thee the ward the warder thee steend the will the will the will the mare the will thee fo
#
# ----- Temperature: 0.5
# ----- Generating with seed: "and and strength could equal them.
# well,"
# and and strength could equal them.
# well, the wither the have mase here in the herting.
#
# iring ascencerio:
# he here the were theif uspe to my me of the wooll love that the with i his with theees the wardos, there the grienss and thee vingersser enver the didse,
# and with have then the wath stould and the orte
# then the berest ond net his but the wall have connes.
#
# wiricentres:
# i have the beare for here my the graice
# thou donather illagh her
#
# ----- Temperature: 1.0
# ----- Generating with seed: "and and strength could equal them.
# well,"
# and and strength could equal them.
# well, sain, bating. thuscelk thus my have theie nod i weard.
#
# wownder:
# why doush enoraues; i fall ssent's coppercion,
#
# lard:
# metroris'r with his moon to hexelthar?
#
# inglicai!:
# for king and fustiteweld with aknneds our tham erecountrates.
#
# blaventio:
# o'll seave o' mather paice.
#
# mortei:
# tare of weme to bultimane tresbly live to
# cencytent?
#
# jarst:
# i thincken ertyo hey toing feprens itcent
# thes, for, to h
#
# Epoch 3
# 2905/2905 ━━━━━━━━━━━━━━━━━━━━ 307s 106ms/step - loss: 1.8630
#
# ----- Temperature: 0.2
# ----- Generating with seed: " with one that
# loved her: the ballad is "
#  with one that
# loved her: the ballad is menter him the deant
# the mast the word the have the propperes.
#
# petruchio:
# now the warle the dound and the prove the didst the counder
# thou are the wand the forther the propies,
# the was the sould the have the propest the disser,
# the warll the proster and the words the waster
# the manter the stand and the wand the wards the forders.
#
# poriolanus:
# i thou have me have the wath the will the prowned
# that
#
# ----- Temperature: 0.5
# ----- Generating with seed: " with one that
# loved her: the ballad is "
#  with one that
# loved her: the ballad is the mart on the reart.
# if the have and that shall bet the rught.
#
# though stringher:
# you are a will it net you hever hene--
# this stould to the will but i have the wister
# the prose to make and the prive be this are and my tourd.
#
# coniolana:
# be thus say not and he would where the shall,
# and for the servin us it our son wheren
# bets the mast it the love with my riader'd with the distare.
#
# knowned:
# i so
#
# ----- Temperature: 1.0
# ----- Generating with seed: " with one that
# loved her: the ballad is "
#  with one that
# loved her: the ballad is to heathor, for loven
# put iscef noudo prade a monout one mole;
# and mote with in thou! me pruily for of,
# angly digling of mare at, wild the touth.
# which to bidnterous? and the other biod than him;
# and thou trum i no musterce thebliet thes.
# though hervone how wanged the wo des: our .
# thou authse stakert.
#
# thousels, praze, look is to imare,
# whither a wors, and harm dear that lown,
# 'this sey and i ou
#
# Epoch 4
# 2905/2905 ━━━━━━━━━━━━━━━━━━━━ 305s 105ms/step - loss: 1.7566
#
# ----- Temperature: 0.2
# ----- Generating with seed: " course toward tewksbury:
# we, having now"
#  course toward tewksbury:
# we, having now the will not so war the seart,
# and the will we have the beath and the will the mant
# the man the son the well the warly and the wast
# the will not the will he was deather, the come
# that i stand the will with the world and the wears,
# and the reath and the world and the will
# the was her the worth and the see the counded
# the seath as the wast the prose the was here
# the hand the was the will not the be
#
# ----- Temperature: 0.5
# ----- Generating with seed: " course toward tewksbury:
# we, having now"
#  course toward tewksbury:
# we, having now in the tell with the sather
# when were a promperte, the sight and a save
# and and death the 'tring have sir the kall,
# and so do the pratued, and thee the weaths
# and suth here is that i be the vill and and the
# to hast thee so mare is nor my lord, far his beting to me thee the hathand
# the prive the prove and your the with and be
# and me bearth the world be of the courter
# and shall a wirt with he word
#
# ----- Temperature: 1.0
# ----- Generating with seed: " course toward tewksbury:
# we, having now"
#  course toward tewksbury:
# we, having now for thy nedmels, why, i am, am.
#
# frovio:
# wiblay, which upon my are till come are ppastict,
# miser livost scolf, lor ant the reag the stalkn xo shall
# you have the cabfst tigen a liast my ulon?
#
# isabella:
# o, he well i san his home change-bidst thene
# where to they away why well, in by which.
#
# sirilio:
# hore there ame aif uil a-wordman
# ''ll be wostrer: our jeatond withis, it thee'er condlay.
#
# stammick:
